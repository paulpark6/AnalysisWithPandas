# %% [markdown]
# ## Saving out Data (Exporting into Desired Format)

# %%
import pandas as pd
df = pd.read_csv('./../DataSet/pokemon_data.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
cols = list(df.columns.values) # cols are list of column names
#df = df[['Name'] + ['Type1'] + ['Type2'] + ['Generation'] + ['Legendary'] + [cols[4:10]] + ['Total']]
df = df[cols[0:4] + [cols[-2]] + [cols[-3]] + cols[4:10] + [cols[-1]]]
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  Generation  HP  \
# 0      1              Bulbasaur    Grass  Poison      False           1  45
# 1      2                Ivysaur    Grass  Poison      False           1  60
# 2      3               Venusaur    Grass  Poison      False           1  80
# 3      3  VenusaurMega Venusaur    Grass  Poison      False           1  80
# 4      4             Charmander     Fire     NaN      False           1  39
# ..   ...                    ...      ...     ...        ...         ...  ..
# 795  719                Diancie     Rock   Fairy       True           6  50
# 796  719    DiancieMega Diancie     Rock   Fairy       True           6  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True           6  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True           6  80
# 799  721              Volcanion     Fire   Water       True           6  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Total
# ...

# %% [markdown]
# ### creating new updated data

# %%
df.to_csv('./../DataSet/','modified.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df.to_csv('./../DataSet/','modified.csv')
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
# ...
