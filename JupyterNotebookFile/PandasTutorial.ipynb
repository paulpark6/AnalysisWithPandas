# %% [markdown]
# ## Loading Data Into Pandas

# %%
import pandas as pd

df = pd.read_csv('./../DataSet/pokemon_data.csv')
# df_tabs = pd.readcsv(''./../DataSet/pokemon_data.csv', delimiter='\t')

# %% [markdown]
# ## Reading First 3 Lines of data

# %%
df.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %% [markdown]
# ## Reading last 3 lines of data

# %%
df.tail(3)
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
## read headers
print(df.columns)
print('-------------------------------------------------------\n')

## Read each Column
print(df['Name'][0:5])
print('-------------------------------------------------------\n')
print(df[['Name', 'Type 1', 'HP']])
print('-------------------------------------------------------\n')


## Read Each Row
print(df.head(4))
print('-------------------------------------------------------\n')


## Read a specific Location (Row,Column)
print(df.iloc[2,1])
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
# -------------------------------------------------------
#
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object
# -------------------------------------------------------
#
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]
# ...

# %% [markdown]
# ## Getting Specific rows with For loop

# %%
for index, row in df.iterrows():
    print(index, row['Attack'])
# Out:
# 0 49
# 1 62
# 2 82
# 3 100
# 4 52
# 5 64
# 6 84
# 7 130
# 8 104
# 9 48
# 10 63
# 11 83
# 12 103
# 13 30
# 14 20
# 15 45
# 16 35
# 17 25
# 18 90
# 19 150
# 20 45
# 21 60
# 22 80
# 23 80
# 24 56
# 25 81
# 26 60
# 27 90
# 28 60
# 29 85
# 30 55
# 31 90
# 32 75
# 33 100
# 34 47
# 35 62
# 36 92
# 37 57
# 38 72
# 39 102
# 40 45
# 41 70
# 42 41
# 43 76
# 44 45
# 45 70
# 46 45
# 47 80
# 48 50
# 49 65
# 50 80
# 51 70
# 52 95
# 53 55
# 54 65
# 55 55
# 56 80
# 57 45
# 58 70
# 59 52
# 60 82
# 61 80
# 62 105
# 63 70
# 64 110
# 65 50
# 66 65
# 67 95
# 68 20
# 69 35
# 70 50
# 71 50
# 72 80
# 73 100
# 74 130
# 75 75
# 76 90
# 77 105
# 78 40
# 79 70
# 80 80
# 81 95
# 82 120
# 83 85
# 84 100
# 85 65
# 86 75
# 87 75
# 88 35
# 89 60
# 90 65
# 91 85
# 92 110
# 93 45
# 94 70
# 95 80
# 96 105
# 97 65
# 98 95
# 99 35
# 100 50
# 101 65
# 102 65
# 103 45
# 104 48
# 105 73
# 106 105
# 107 130
# 108 30
# 109 50
# 110 40
# 111 95
# 112 50
# 113 80
# 114 120
# 115 105
# 116 55
# 117 65
# 118 90
# 119 85
# 120 130
# ...

# %% [markdown]
# ## Finding pokemon with the most Attack Damage

# %%
m = 0
pokemon = list()
for index, row in df.iterrows():
    if m <= row['Attack']:
        m = row['Attack']
        pokemon = row

print("Name: ",  pokemon['Name'], "\nAttack: ", pokemon['Attack'])
# Out:
# Name:  MewtwoMega Mewtwo X
# Attack:  190
